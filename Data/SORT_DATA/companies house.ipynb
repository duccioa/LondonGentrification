# %%
import pandas as pd
pd.set_option('display.max_rows', 300, 'display.notebook_repr_html', True)

# %%
ch_headers = ['Company Name', 'Company Number', 'Addressline1', 'Adressline2', 
              'City', 'Postcode', 'CompanyCategory','CompanyStatus', 'AccountCategory', 
              'SICcode', 'URI']

# %%
ch_df = pd.read_csv('example.csv', header=0, names=ch_headers)

# %%
ch_df
# Out:
#                                            Company Name Company Number  \
# 0                               042RESTAURANTANDBAR LTD        8819247
# 1                                      06811517 LIMITED        6811517
# 2                                    0Z CRYSTAL LIMITED        9052918
# 3                                    1 MINUTE FOODS LTD        7322606
# 4                                1 STOP EXPRESS LIMITED        8260190
# 5                               104 TURKISH BBQ LIMITED        8307316
# 6                               121 FOOD SUPPLY LIMITED        7257378
# 7                                  15A HAY HILL LIMITED        7310768
# 8                                      180 EAST LIMITED        8808380
# 9                               181 KINGS CROSS LIMITED        8490721
# 10                                   189 PICCADILLY LTD        8320089
# 11                                             1906 LTD        7373215
# ...
