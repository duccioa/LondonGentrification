# %% [markdown]
# <b>Spatial Analysis for London Gentrification Project</b>

# %%
#Load packages
import pandas as pd
import numpy as np
import fiona #for reading shapefiles

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors
from matplotlib.colors import Normalize

from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon 
from shapely.prepared import prep #for processing shapefiles to make operations quicker

from itertools import chain

from mpl_toolkits.basemap import Basemap #for mapping

# %%
#Set working directory
import os
os.chdir("C:/Users/Claire/Google Drive/LondonGentrification")

# %%
#CHECK PROJECTION
#Import OGR module
from osgeo import ogr
#Activate OGR Shapefile driver
shp_driver = ogr.GetDriverByName('ESRI Shapefile')
#Open shapefile with OGR
shp_dataset = shp_driver.Open(r'Data/ESRI/London_ward_CityMerged.shp')
#Access layer information
shp_layer = shp_dataset.GetLayer()
#get coordinate information using GetSpatialRef() function
shp_srs = shp_layer.GetSpatialRef()
#Pront spatial reference system on screen
#print shp_srs

# %%
#CREATE PANDAS DATAFRAME TO WRITE FEATURES FROM SHAPEFILE

ward_names = []
ward_code = []

for feature in shp_layer:
    name = feature.GetField("NAME")
    code = feature.GetField("GSS_Code")
    ward_names.append(name)
    ward_code.append(code)
    
ward_variables = pd.DataFrame(index=ward_code, columns = ['Ward Name'], data=ward_names)

# %%
#IMPORT THE .CSV WITH INCOME INFORMATION
ward_income = pd.read_csv("Data/modelled-household-income-estimates-wards.csv", index_col = 'Code')

# %%
#JOIN INCOME INFORMATION TO 
ward_variables = ward_variables.join(ward_income['Median 2012_13'] , on=None, how='left', lsuffix='', rsuffix='', sort=False)

#Rename Column
ward_variables=ward_variables.rename(columns = {'Median 2012_13':'Median Income 2012_13'})

# %%
#CATEGORISE AS HIGH LOW (HIGHER OR LOWER THAN MEAN)

#Caluclate mean
mean_income = np.mean(ward_variables['Median Income 2012_13'])

#Define function for categories
def income_category (row):
    if row['Median Income 2012_13'] >= mean_income:
          return 'High'
    if row['Median Income 2012_13'] < mean_income:
          return 'Low'
    return 'Other'

#Apply function to create new dataframe coloumn
ward_variables['Income Category'] = ward_variables.apply(lambda row: income_category (row), axis=1)

# %%
#CREATE A SPECTRUM OF COLOURS
N = 7 #Number of intervals
increment = 255/(N+1)
RGB_tuples = [((230-(x*increment)), ((230-(x*increment))), 255) for x in range(N)]

#Convert to hex color format for mapping
hex_colour = []
for x in RGB_tuples:
    hexa = '#%02x%02x%02x' % (x)
    hex_colour.append(hexa)

print RGB_tuples
print hex_colour
# Out:
# [(230, 230, 255), (199, 199, 255), (168, 168, 255), (137, 137, 255), (106, 106, 255), (75, 75, 255), (44, 44, 255)]
# ['#e6e6ff', '#c7c7ff', '#a8a8ff', '#8989ff', '#6a6aff', '#4b4bff', '#2c2cff']

# %%
#VISUALISE COLOURS
cmap = matplotlib.colors.ListedColormap(hex_colour, name = 'from_list', N=N)

fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])

cb1 = matplotlib.colorbar.ColorbarBase(ax1, cmap=cmap,
                                orientation='horizontal')

plt.show()

# %%
#FUNCTION TO ASSIGN COLOURS (EQUAL INTERVAL)
def color_assign (row, data, var):
    minimum = data.min()
    maximum = data.max()
    N=len(hex_colour)
    intervals = np.linspace(minimum, maximum, num=N+1)
    for x in range(N):
        if row[var] <= intervals[x+1]:
            return hex_colour[x]

# %%
#APPLY FUNCTION TO DATAFRAME
ward_variables['Income Colour'] = ward_variables.apply(lambda row: color_assign(row, 
                                                                                ward_variables['Median Income 2012_13'], 'Median Income 2012_13'), axis=1)

# %%
#ADD POSITION COLUMN

position = []

for i in range(len(ward_variables['Ward Name'])):
    posi = i
    position.append(i)
    
ward_variables['Position'] = position

ward_variables
# Out:
#                             Ward Name  Median Income 2012_13 Income Category  \
# E05000405           Chessington South                  38310             Low
# E05000414      Tolworth and Hook Rise                  37840             Low
# E05000401                  Berrylands                  42330            High
# E05000400                   Alexandra                  41390            High
# E05000402                    Beverley                  40700            High
# E05000406                 Coombe Hill                  45650            High
# E05000404  Chessington North and Hook                  37230             Low
# E05000413               Surbiton Hill                  43160            High
# E05000410                  Old Malden                  41760            High
# E05000412                  St. Mark's                  44930            High
# E05000408                       Grove                  41410            High
# E05000403                     Canbury                  45600            High
# E05000409                    Norbiton                  34650             Low
# E05000407                 Coombe Vale                  44320            High
# E05000411                   St. James                  41850            High
# E05000415                       Tudor                  48530            High
# E05000150               Coulsdon East                  42660            High
# E05000162        Selsdon and Ballards                  45320            High
# E05000151               Coulsdon West                  46610            High
# E05000167                      Waddon                  34630             Low
# E05000156                      Kenley                  44160            High
# E05000159                      Purley                  44600            High
# E05000160                 Sanderstead                  47030            High
# E05000155                  Heathfield                  39770            High
# E05000153                   Fairfield                  39130             Low
# E05000149                 Broad Green                  31000             Low
# E05000168               West Thornton                  32400             Low
# E05000148               Bensham Manor                  33530             Low
# E05000158                     Norbury                  36810             Low
# E05000157               New Addington                  28770             Low
# ...                               ...                    ...             ...
# E05000494                    West Ham                  32310             Low
# E05000489              Plaistow North                  30740             Low
# E05000484           Forest Gate South                  34550             Low
# E05000476                      Boleyn                  31630             Low
# E05000480            East Ham Central                  32380             Low
# E05000486           Green Street West                  31080             Low
# E05000485           Green Street East                  31570             Low
# E05000481              East Ham North                  32340             Low
# E05000493                    Wall End                  32330             Low
# E05000483           Forest Gate North                  34270             Low
# E05000488                  Manor Park                  31580             Low
# E05000487               Little Ilford                  29730             Low
# E05000032                   Gascoigne                  29480             Low
# E05000039                      Thames                  32580             Low
# E05000038                       River                  33490             Low
# E05000041                     Village                  31960             Low
# E05000026                       Abbey                  33920             Low
# E05000035                  Longbridge                  40570            High
# E05000031                    Eastbury                  32870             Low
# E05000033                  Goresbrook                  33250             Low
# E05000036                  Mayesbrook                  31530             Low
# E05000028                   Becontree                  33000             Low
# E05000027                      Alibon                  32470             Low
# E05000040                     Valence                  33200             Low
# E05000034                       Heath                  31340             Low
# E05000042                   Whalebone                  37180             Low
# E05000030                   Eastbrook                  37400             Low
# E05000029              Chadwell Heath                  33920             Low
# E05000037                    Parsloes                  31860             Low
# E09000001              City of London                  63620            High
#
#           Income Colour  Position
# E05000405       #c7c7ff         0
# E05000414       #c7c7ff         1
# E05000401       #c7c7ff         2
# E05000400       #c7c7ff         3
# E05000402       #c7c7ff         4
# E05000406       #a8a8ff         5
# E05000404       #c7c7ff         6
# E05000413       #a8a8ff         7
# E05000410       #c7c7ff         8
# E05000412       #a8a8ff         9
# E05000408       #c7c7ff        10
# E05000403       #a8a8ff        11
# E05000409       #c7c7ff        12
# E05000407       #a8a8ff        13
# E05000411       #c7c7ff        14
# E05000415       #a8a8ff        15
# E05000150       #c7c7ff        16
# E05000162       #a8a8ff        17
# E05000151       #a8a8ff        18
# E05000167       #c7c7ff        19
# E05000156       #a8a8ff        20
# E05000159       #a8a8ff        21
# E05000160       #a8a8ff        22
# E05000155       #c7c7ff        23
# E05000153       #c7c7ff        24
# E05000149       #e6e6ff        25
# E05000168       #e6e6ff        26
# E05000148       #e6e6ff        27
# E05000158       #c7c7ff        28
# E05000157       #e6e6ff        29
# ...                 ...       ...
# E05000494       #e6e6ff       595
# E05000489       #e6e6ff       596
# E05000484       #c7c7ff       597
# E05000476       #e6e6ff       598
# E05000480       #e6e6ff       599
# E05000486       #e6e6ff       600
# E05000485       #e6e6ff       601
# E05000481       #e6e6ff       602
# E05000493       #e6e6ff       603
# E05000483       #c7c7ff       604
# E05000488       #e6e6ff       605
# E05000487       #e6e6ff       606
# E05000032       #e6e6ff       607
# E05000039       #e6e6ff       608
# E05000038       #e6e6ff       609
# E05000041       #e6e6ff       610
# E05000026       #e6e6ff       611
# E05000035       #c7c7ff       612
# E05000031       #e6e6ff       613
# E05000033       #e6e6ff       614
# E05000036       #e6e6ff       615
# E05000028       #e6e6ff       616
# E05000027       #e6e6ff       617
# E05000040       #e6e6ff       618
# E05000034       #e6e6ff       619
# E05000042       #c7c7ff       620
# E05000030       #c7c7ff       621
# E05000029       #e6e6ff       622
# E05000037       #e6e6ff       623
# E09000001       #6a6aff       624
#
# [625 rows x 5 columns]

# %%
#EXPORT CSV
ward_variables.to_csv('Data/claire_ward_variables.csv', index_label = 'Code')

# %%
#IMPORT TOKEN DATA
tokens_spatial = pd.read_csv("Data/FoodPremises/tokens_spatial.csv")

# %%
#https://glenbambrick.com/2016/01/24/reproject-shapefile/

def getWKT_PRJ (epsg_code):
    import urllib
    wkt = urllib.urlopen("http://spatialreference.org/ref/epsg/{0}/prettywkt/".format(epsg_code))
    remove_spaces = wkt.read().replace(" ","")
    output = remove_spaces.replace("\n", "")
    return output

# %%
#https://glenbambrick.com/2016/01/24/reproject-shapefile/

#CODE TO CONVERT COORDINATE SYSTEM
import shapefile
import pyproj
from pyproj import Proj, transform

#Reader object to access data
shpf = shapefile.Reader("Data/ESRI/London_Ward_CityMerged.shp")

#Create a Writer object to write data to as a new Shapefile.
wgs_shp = shapefile.Writer(shapefile.POLYGON)

#Set variables for access to the field information of both the original and new Shapefile.
fields = shpf.fields
wgs_fields = wgs_shp.fields

#Grab field information from original and copy into the new shapefile (passing over deletion flag)
for name in fields:
    if type(name) == "tuple":
        continue
    else:
        args = name
        wgs_shp.field(*args)
        
#Populate with attribute information
records = shpf.records() #Access records of original file

#Copy into new
for row in records:
    args = row
    wgs_shp.record(*args)

#define input and output projection
input_projection = pyproj.Proj("+init=EPSG:27700") #osgb36
output_projection = pyproj.Proj("+init=EPSG:4326") #wgs84

#Access geometry of original file
geom = shpf.shapes()

#Iterate through all the points in the shapefile and trandsform from BNG to WGS
#ONLY WORKS FOR NON-MULTIPART POLYGONS
for feature in geom:
    # if there is only one part
    #if len(feature.parts) == 1:
        # create empty list to store all the coordinates
        poly_list = []
        # get each coord that makes up the polygon
        for coords in feature.points:
            x, y = coords[0], coords[1]
            # tranform the coord
            new_x, new_y = pyproj.transform(input_projection, output_projection, x, y)
            # put the coord into a list structure
            poly_coord = [float(new_x), float(new_y)]
            # append the coords to the polygon list
            poly_list.append(poly_coord)
        # add the geometry to the shapefile.
        wgs_shp.poly(parts=[poly_list])
        
#Save shapefile to folder
wgs_shp.save('Data/ESRI/london_wards_WGS84.shp')

#And generate the projection file for it.
prj = open('Data/ESRI/london_wards_WGS84.prj', "w")
epsg = getWKT_PRJ("4326")
prj.write(epsg)
prj.close()

# %%
from geopandas import GeoDataFrame
from shapely.geometry import Point

crs = None
geometry = [Point(xy) for xy in zip(tokens_spatial.lon, tokens_spatial.lat)]
geo_df = GeoDataFrame(tokens_spatial, crs=crs, geometry=geometry)

# %%
#http://rexdouglass.com/fast-spatial-joins-in-python-with-a-spatial-index/

import shapefile
import shapely

#Load the shapefile of polygons and convert it to shapely polygon objects
polygons_sf = shapefile.Reader("Data/ESRI/london_wards_WGS84.shp")
polygon_shapes = polygons_sf.shapes()
polygon_points = [q.points for q in polygon_shapes ]
from shapely.geometry import Polygon
polygons = [Polygon(q) for q in polygon_points]

points = geometry

# %%
len(points)
# Out:
# 149473

# %%
#Build a spatial index based on the bounding boxes of the polygons
from rtree import index
idx = index.Index()
count = -1
for q in polygon_shapes:
    count +=1
    idx.insert(count, q.bbox)

# %%
point_coords = []

for i in range(len(points)):
    a = ([points[i].x, points[i].y])
    point_coords.append(a)

# %%
len(point_coords)
# Out:
# 149473

# %%
#Assign one or more matching polygons to each point

matches = []

for i in range(len(points)): #Iterate through each point
    temp= None
    print "Point ", i

    #Iterate only through the bounding boxes which contain the point
    for j in idx.intersection(point_coords[i]):
        #Verify that point is within the polygon itself not just the bounding box
        if points[i].within(polygons[j]):
            print "Match found! ",j
            temp=j
            break
    matches.append(temp) #Either the first match found, or None for no matches
# Out:
# Point  0
# Match found!  619
# Point  1
# Match found!  619
# Point  2
# Match found!  619
# Point  3
# Match found!  619
# Point  4
# Match found!  619
# Point  5
# Match found!  623
# Point  6
# Match found!  623
# Point  7
# Match found!  618
# Point  8
# Match found!  618
# Point  9
# Match found!  611
# Point  10
# Match found!  611
# Point  11
# Match found!  610
# Point  12
# Match found!  610
# Point  13
# Match found!  611
# Point  1191
# Match found!  611
# Point  1192
# Match found!  614
# Point  1193
# Match found!  614
# Point  1194
# Match found!  614
# Point  1195
# Match found!  614
# Point  1196
# Match found!  614
# Point  1197
# Match found!  352
# Point  1198
# Match found!  352
# Point  1199
# Match found!  611
# Point  1200
# Match found!  611
# Point  1201
# Match found!  611
# Point  1202
# Match found!  610
# Point  1203
# Match found!  610
# Point  1204
# Match found!  610
# Point  1205
# Match found!  613
# Point  1206
# Match found!  613
# Point  1207
# Match found!  613
# Point  1208
# Match found!  616
# Point  1209
# Match found!  616
# Point  1210
# Match found!  616
# Point  1211
# Match found!  616
# Point  1212
# Match found!  608
# Point  1213
# Match found!  608
# Point  1214
# Match found!  608
# Point  1215
# Match found!  619
# Point  1216
# Match found!  619
# Point  1217
# Match found!  619
# Point  1218
# Match found!  620
# Point  1219
# Match found!  620
# Point  1220
# Match found!  620
# Point  1221
# Match found!  620
# Point  1222
# Match found!  620
# Point  1223
# Match found!  620
# Point  1224
# Match found!  620
# Point  1225
# Match found!  618
# Point  1226
# Match found!  618
# Point  1227
# Match found!  618
# Point  1228
# Match found!  618
# Point  1229
# Match found!  618
# Point  1230
# Match found!  618
# Point  1231
# Match found!  618
# Point  1232
# Match found!  618
# Point  1233
# Match found!  618
# Point  1234
# Match found!  611
# Point  1235
# Match found!  611
# Point  1236
# Match found!  623
# Point  1237
# Match found!  623
# Point  1238
# Match found!  623
# Point  1239
# Match found!  623
# Point  1240
# Match found!  611
# Point  1241
# Match found!  610
# Point  1242
# Match found!  610
# Point  1243
# Match found!  610
# Point  1244
# Match found!  616
# Point  1245
# Match found!  616
# Point  1246
# Match found!  616
# Point  1247
# Match found!  616
# Point  1248
# Match found!  616
# Point  1249
# Match found!  616
# Point  1250
# Match found!  620
# Point  1251
# Match found!  620
# Point  1252
# Match found!  612
# Point  1253
# Match found!  612
# Point  1254
# Match found!  612
# Point  1255
# Match found!  612
# Point  1256
# Match found!  612
# Point  1257
# Match found!  607
# Point  1258
# Match found!  607
# Point  1259
# Match found!  607
# Point  1260
# Match found!  607
# Point  1261
# Match found!  616
# Point  1262
# Match found!  616
# Point  1263
# Match found!  615
# Point  1264
# Match found!  615
# Point  1265
# Match found!  615
# Point  1266
# Match found!  615
# Point  1267
# Match found!  615
# Point  1268
# Match found!  615
# Point  1269
# Match found!  618
# Point  1270
# Match found!  618
# Point  1271
# Match found!  610
# Point  1272
# Match found!  610
# Point  1273
# Match found!  610
# Point  1274
# Match found!  616
# Point  1275
# Match found!  616
# Point  1276
# Match found!  616
# Point  1277
# Match found!  609
# Point  1278
# Match found!  609
# Point  1279
# Match found!  609
# Point  1280
# Match found!  611
# Point  1281
# Match found!  611
# Point  1282
# Match found!  611
# Point  1283
# Match found!  616
# Point  1284
# Match found!  616
# Point  1285
# Match found!  616
# Point  1286
# Match found!  617
# Point  1287
# Match found!  617
# Point  1288
# Match found!  617
# Point  1289
# Match found!  614
# Point  1290
# Match found!  614
# Point  1291
# Match found!  607
# Point  1292
# Match found!  607
# Point  1293
# Match found!  622
# Point  1294
# Match found!  622
# Point  1295
# Match found!  612
# Point  1296
# Match found!  612
# Point  1297
# Match found!  612
# Point  1298
# Match found!  612
# Point  1299
# Match found!  612
# Point  1300
# Match found!  613
# Point  1301
# Match found!  613
# Point  1302
# Match found!  611
# Point  1303
# Match found!  621
# Point  1304
# Match found!  621
# Point  1305
# Match found!  623
# Point  1306
# Match found!  609
# Point  1307
# Match found!  607
# Point  1308
# Match found!  611
# Point  1309
# Match found!  610
# Point  1310
# Match found!  607
# Point  1311
# Match found!  611
# Point  1312
# Match found!  611
# Point  1313
# Match found!  611
# Point  1314
# Match found!  620
# Point  1315
# Match found!  620
# Point  1316
# Match found!  620
# Point  1317
# Match found!  620
# Point  1318
# Match found!  616
# Point  1319
# Match found!  616
# Point  1320
# Match found!  616
# Point  1321
# Match found!  616
# Point  1322
# Match found!  616
# Point  1323
# Match found!  612
# Point  1324
# Match found!  612
# Point  1325
# Match found!  612
# Point  1326
# Match found!  612
# Point  1327
# Match found!  617
# Point  1328
# Match found!  617
# Point  1329
# Match found!  617
# Point  1330
# Match found!  611
# Point  1331
# Match found!  611
# Point  1332
# Match found!  618
# Point  1333
# Match found!  618
# Point  1334
# Match found!  613
# Point  1335
# Match found!  622
# Point  1336
# Match found!  622
# Point  1337
# Match found!  622
# Point  1338
# Match found!  619
# Point  1339
# Match found!  619
# Point  1340
# Match found!  616
# Point  1341
# Match found!  612
# Point  1342
# Match found!  612
# Point  1343
# Match found!  623
# Point  1344
# Match found!  623
# Point  1345
# Match found!  623
# Point  1346
# Match found!  623
# Point  1347
# Match found!  623
# Point  1348
# Match found!  610
# Point  1349
# Match found!  610
# Point  1350
# Match found!  611
# Point  1351
# Match found!  611
# Point  1352
# Match found!  613
# Point  1353
# Match found!  613
# Point  1354
# Match found!  613
# Point  1355
# Match found!  615
# Point  1356
# Match found!  615
# Point  1357
# Match found!  612
# Point  1358
# Match found!  612
# Point  1359
# Match found!  612
# Point  1360
# Match found!  612
# Point  1361
# Match found!  612
# Point  1362
# Match found!  612
# Point  1363
# Match found!  622
# Point  1364
# Match found!  622
# Point  1365
# Match found!  622
# Point  1366
# Match found!  622
# Point  1367
# Match found!  622
# Point  1368
# Match found!  622
# Point  1369
# Match found!  622
# Point  1370
# Match found!  622
# Point  1371
# Match found!  622
# Point  1372
# Match found!  622
# Point  1373
# Match found!  622
# Point  1374
# Match found!  622
# Point  1375
# Match found!  622
# Point  1376
# Match found!  622
# Point  1377
# Match found!  622
# Point  1378
# Match found!  622
# Point  1379
# Match found!  622
# Point  1380
# Match found!  622
# Point  1381
# Match found!  609
# Point  1382
# Match found!  609
# Point  1383
# Match found!  609
# Point  1384
# Match found!  609
# Point  1385
# Match found!  612
# Point  1386
# Match found!  615
# Point  1387
# Match found!  615
# Point  1388
# Match found!  622
# Point  1389
# Match found!  615
# Point  1390
# Match found!  615
# Point  1391
# Match found!  620
# Point  1392
# Point  53028
# Match found!  563
# Point  53029
# Match found!  563
# Point  53030
# Match found!  565
# Point  53031
# Match found!  565
# Point  53032
# Match found!  551
# Point  53033
# Match found!  551
# Point  53034
# Match found!  551
# Point  53035
# Match found!  551
# Point  53036
# Match found!  549
# Point  53037
# Match found!  549
# Point  53038
# Match found!  562
# Point  53039
# Match found!  562
# Point  53040
# Match found!  555
# Point  53041
# Match found!  555
# Point  53042
# Match found!  555
# Point  53043
# Match found!  553
# Point  53044
# Match found!  553
# Point  53045
# Match found!  553
# Point  53046
# Match found!  561
# Point  53047
# Match found!  549
# Point  53048
# Match found!  549
# Point  53049
# Match found!  549
# Point  53050
# Match found!  554
# Point  53051
# Match found!  554
# Point  53052
# Match found!  554
# Point  53053
# Match found!  553
# Point  53054
# Match found!  553
# Point  53055
# Match found!  558
# Point  53056
# Match found!  558
# Point  53057
# Match found!  549
# Point  53058
# Match found!  549
# Point  53059
# Match found!  551
# Point  53060
# Match found!  551
# Point  53061
# Match found!  551
# Point  53062
# Match found!  551
# Point  53063
# Match found!  551
# Point  53064
# Match found!  566
# Point  53065
# Match found!  566
# Point  53066
# Match found!  566
# Point  53067
# Match found!  551
# Point  53068
# Match found!  551
# Point  53069
# Match found!  564
# Point  53070
# Match found!  564
# Point  53071
# Match found!  564
# Point  53072
# Match found!  550
# Point  53073
# Match found!  550
# Point  53074
# Match found!  564
# Point  53075
# Match found!  564
# Point  53076
# Match found!  564
# Point  53077
# Match found!  549
# Point  53078
# Match found!  549
# Point  53079
# Match found!  554
# Point  53080
# Match found!  554
# Point  53081
# Match found!

# %%
len(matches)
# Out:
# 5551

# %%
#Add matching wards to spatial tokens
geo_df['Matching Wards'] = matches
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8a82e3e980b2> in <module>()
#       1 #Add matching wards to spatial tokens
# ----> 2 geo_df['Matching Wards'] = matches
#
# C:\Users\Claire\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\frame.pyc in __setitem__(self, key, value)
#    2346         else:
#    2347             # set column
# -> 2348             self._set_item(key, value)
#    2349
#    2350     def _setitem_slice(self, key, value):
#
# C:\Users\Claire\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\frame.pyc in _set_item(self, key, value)
#    2412
#    2413         self._ensure_valid_index(value)
# -> 2414         value = self._sanitize_column(key, value)
#    2415         NDFrame._set_item(self, key, value)
#    2416
#
# C:\Users\Claire\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\frame.pyc in _sanitize_column(self, key, value)
#    2570
#    2571             # turn me into an ndarray
# -> 2572             value = _sanitize_index(value, self.index, copy=False)
#    2573             if not isinstance(value, (np.ndarray, Index)):
#    2574                 if isinstance(value, list) and len(value) > 0:
#
# C:\Users\Claire\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\core\series.pyc in _sanitize_index(data, index, copy)
#    2819
#    2820     if len(data) != len(index):
# -> 2821         raise ValueError('Length of values does not match length of ' 'index')
#    2822
#    2823     if isinstance(data, PeriodIndex):
#
# ValueError: Length of values does not match length of index

# %%
#Merge tokens to ward variable information 
merged_tokens = geo_df.merge(ward_variables, left_on='Matching Wards', right_on ='position')

# %%
#Export to csv
merged_tokens.to_csv('Data/spatial_tokens_ward.csv')

# %%
#Create point tuples
geometry = [Point(xy) for xy in zip(tokens_spatial.lon, tokens_spatial.lat)]
